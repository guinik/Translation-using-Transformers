# %%
# %run DataandTokenizer.ipynb
# %run Transformer.ipynb
import time

# %% [markdown]
# # Now that everything is set up all thats left is to train the model

# %%
#This are the parameters that define our transformers
layersnum = 4
modeldim = 128
dff = 512 #<- this is for the RELu layers between layers
num_heads = 4 
dropout_rate = 0.1

# %% [markdown]
# To fully complete whats described in the paper we will use the same variable learning rate and learning rate. This can be also found on the tensorflow post

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = modeldim
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(modeldim)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)

# %% [markdown]
# Also since our target will have padding we need to apply a transformation to the loss function

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred) #we calculate the loss first 

    mask = tf.cast(mask, dtype=loss_.dtype) #if a False, means it was zero , which means it was padding
    #and padding shouldnt account for the loss so when multiplying its not counted.
    loss_ *= mask#we apply the mask to it

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)#sum all loses over the length of the tensor of mask


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)
    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)
    #its exactly the same thought but checking if its accurate or not 
    #get when its padding and then not acount it 
    
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
Embed=Embedding()
datos=Data()
tokenizers=Tokenizer()

def tokenize_pairs(es,pt):
    data2=[]
    data2.append(es)
    data2.append(pt)
    pt = Embed.tokenize(data2)[1]
    # Convert from ragged to dense, padding with zeros.
    es=Embed.tokenize(data2)[0]
    # Convert from ragged to dense, padding with zeros.
    return es,pt

maxnum=2
transformer = Transformer(
    num_layers=layersnum,
    d_model=modeldim,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=5000,
    target_vocab_size=5000,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
print(shape2)
print(shape1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8972\1320250318.py in <module>
# ----> 1 print(shape2)
#       2 print(shape1)
#
# NameError: name 'shape2' is not defined

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print('Latest checkpoint restored!!')

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.


BUFFER_SIZE = 20000

BATCH_SIZE = 5
def train_step(inp, tar):
    tar_inp = tar[:,:-1]#(batch,tar_seq_len)
    tar_real = tar[:,1:]

    with tf.GradientTape() as tape:
        predictions, _ = transformer([inp, tar_inp],
                                 training = True)
        loss = loss_function(tar_real, predictions)
    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

    
    #STUFF
examples, metadata = tfds.load('ted_hrlr_translate/es_to_pt', with_info=True,
                               as_supervised=True)


def make_batches(ds):
    return (
      ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .prefetch(tf.data.AUTOTUNE))
    
    
train_examples, val_examples = examples['train'], examples['validation']
train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)

# %%
train_examples, val_examples = examples['train'], examples['validation']
train_batches=make_batches(train_examples)

# %%
EPOCHS=10

for epoch in range(EPOCHS):
    start = time.time()
    checkpoint_path = "./checkpoints/train"

    ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

    ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

    if ckpt_manager.latest_checkpoint:
        ckpt.restore(ckpt_manager.latest_checkpoint)
        print('Latest checkpoint restored!!')
    train_loss.reset_states()
    train_accuracy.reset_states()
    for (batch, (inp, tar)) in enumerate(train_batches):
        train_step(inp, tar)

    
        if batch % 50 == 0:
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if batch % 500 == 0:
            ckpt_save_path = ckpt_manager.save()
            print(f'Saving checkpoint for epoch {epoch+1} and for Batch {batch} at {ckpt_save_path}')

    if (epoch + 1) % 1 == 0:
        ckpt_save_path = ckpt_manager.save()
        print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

        print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 8.6267 Accuracy 0.0000
# Saving checkpoint for epoch 1 and for Batch 0 at ./checkpoints/train\ckpt-1
# Epoch 1 Batch 50 Loss 8.5195 Accuracy 0.0003
# Epoch 1 Batch 100 Loss 8.4130 Accuracy 0.0187
# Epoch 1 Batch 150 Loss 8.3151 Accuracy 0.0281
# Epoch 1 Batch 200 Loss 8.2059 Accuracy 0.0323
# Epoch 1 Batch 250 Loss 8.0802 Accuracy 0.0350
# Epoch 1 Batch 300 Loss 7.9427 Accuracy 0.0364
# Epoch 1 Batch 350 Loss 7.7946 Accuracy 0.0378
# Epoch 1 Batch 400 Loss 7.6487 Accuracy 0.0390
# Epoch 1 Batch 450 Loss 7.5123 Accuracy 0.0428
# Epoch 1 Batch 500 Loss 7.3978 Accuracy 0.0487
# Saving checkpoint for epoch 1 and for Batch 500 at ./checkpoints/train\ckpt-2
# Epoch 1 Batch 550 Loss 7.2967 Accuracy 0.0532
# Epoch 1 Batch 600 Loss 7.2093 Accuracy 0.0572
# Epoch 1 Batch 650 Loss 7.1292 Accuracy 0.0612
# Epoch 1 Batch 700 Loss 7.0621 Accuracy 0.0650
# Epoch 1 Batch 750 Loss 6.9963 Accuracy 0.0691
# Epoch 1 Batch 800 Loss 6.9400 Accuracy 0.0727
# Epoch 1 Batch 850 Loss 6.8890 Accuracy 0.0759
# Epoch 1 Batch 900 Loss 6.8405 Accuracy 0.0788
# Epoch 1 Batch 950 Loss 6.7944 Accuracy 0.0815
# Epoch 1 Batch 1000 Loss 6.7526 Accuracy 0.0842
# Saving checkpoint for epoch 1 and for Batch 1000 at ./checkpoints/train\ckpt-3
# Epoch 1 Batch 1050 Loss 6.7151 Accuracy 0.0866
# Epoch 1 Batch 1100 Loss 6.6788 Accuracy 0.0892
# Epoch 1 Batch 1150 Loss 6.6390 Accuracy 0.0920
# Epoch 1 Batch 1200 Loss 6.6036 Accuracy 0.0943
# Epoch 1 Batch 1250 Loss 6.5694 Accuracy 0.0964
# Epoch 1 Batch 1300 Loss 6.5372 Accuracy 0.0986
# Epoch 1 Batch 1350 Loss 6.5059 Accuracy 0.1004
# Epoch 1 Batch 1400 Loss 6.4770 Accuracy 0.1024
# Epoch 1 Batch 1450 Loss 6.4513 Accuracy 0.1040
# Epoch 1 Batch 1500 Loss 6.4229 Accuracy 0.1058
# Saving checkpoint for epoch 1 and for Batch 1500 at ./checkpoints/train\ckpt-4
# Epoch 1 Batch 1550 Loss 6.3991 Accuracy 0.1072
# Epoch 1 Batch 1600 Loss 6.3753 Accuracy 0.1084
# Epoch 1 Batch 1650 Loss 6.3510 Accuracy 0.1099
# Epoch 1 Batch 1700 Loss 6.3307 Accuracy 0.1110
# Epoch 1 Batch 1750 Loss 6.3089 Accuracy 0.1124
# Epoch 1 Batch 1800 Loss 6.2894 Accuracy 0.1136
# Epoch 1 Batch 1850 Loss 6.2722 Accuracy 0.1146
# Epoch 1 Batch 1900 Loss 6.2553 Accuracy 0.1154
# Epoch 1 Batch 1950 Loss 6.2386 Accuracy 0.1164
# Epoch 1 Batch 2000 Loss 6.2229 Accuracy 0.1174
# Saving checkpoint for epoch 1 and for Batch 2000 at ./checkpoints/train\ckpt-5
# Epoch 1 Batch 2050 Loss 6.2047 Accuracy 0.1185
# Epoch 1 Batch 2100 Loss 6.1893 Accuracy 0.1193
# Epoch 1 Batch 2150 Loss 6.1758 Accuracy 0.1203
# Epoch 1 Batch 2200 Loss 6.1626 Accuracy 0.1209
# Epoch 1 Batch 2250 Loss 6.1487 Accuracy 0.1216
# Epoch 1 Batch 2300 Loss 6.1357 Accuracy 0.1223
# Epoch 1 Batch 2350 Loss 6.1228 Accuracy 0.1231
# Epoch 1 Batch 2400 Loss 6.1106 Accuracy 0.1238
# Epoch 1 Batch 2450 Loss 6.0993 Accuracy 0.1244
# Epoch 1 Batch 2500 Loss 6.0867 Accuracy 0.1252
# Saving checkpoint for epoch 1 and for Batch 2500 at ./checkpoints/train\ckpt-6
# Epoch 1 Batch 2550 Loss 6.0755 Accuracy 0.1258
# Epoch 1 Batch 2600 Loss 6.0650 Accuracy 0.1262
# Epoch 1 Batch 2650 Loss 6.0548 Accuracy 0.1267
# Epoch 1 Batch 2700 Loss 6.0445 Accuracy 0.1274
# Epoch 1 Batch 2750 Loss 6.0360 Accuracy 0.1276
# Epoch 1 Batch 2800 Loss 6.0259 Accuracy 0.1282
# Epoch 1 Batch 2850 Loss 6.0169 Accuracy 0.1286
# Epoch 1 Batch 2900 Loss 6.0090 Accuracy 0.1292
# Epoch 1 Batch 2950 Loss 6.0017 Accuracy 0.1294
# Epoch 1 Batch 3000 Loss 5.9940 Accuracy 0.1298
# Saving checkpoint for epoch 1 and for Batch 3000 at ./checkpoints/train\ckpt-7
# Epoch 1 Batch 3050 Loss 5.9844 Accuracy 0.1304
# Epoch 1 Batch 3100 Loss 5.9765 Accuracy 0.1307
# Epoch 1 Batch 3150 Loss 5.9681 Accuracy 0.1311
# Epoch 1 Batch 3200 Loss 5.9611 Accuracy 0.1315
# Epoch 1 Batch 3250 Loss 5.9540 Accuracy 0.1318
# Epoch 1 Batch 3300 Loss 5.9466 Accuracy 0.1321
# Epoch 1 Batch 3350 Loss 5.9392 Accuracy 0.1326
# Epoch 1 Batch 3400 Loss 5.9331 Accuracy 0.1329
# Epoch 1 Batch 3450 Loss 5.9248 Accuracy 0.1333
# Epoch 1 Batch 3500 Loss 5.9179 Accuracy 0.1336
# Saving checkpoint for epoch 1 and for Batch 3500 at ./checkpoints/train\ckpt-8
# Epoch 1 Batch 3550 Loss 5.9101 Accuracy 0.1340
# Epoch 1 Batch 3600 Loss 5.9027 Accuracy 0.1344
# Epoch 1 Batch 3650 Loss 5.8955 Accuracy 0.1348
# Epoch 1 Batch 3700 Loss 5.8884 Accuracy 0.1351
# Epoch 1 Batch 3750 Loss 5.8818 Accuracy 0.1355
# Epoch 1 Batch 3800 Loss 5.8754 Accuracy 0.1359
# Epoch 1 Batch 3850 Loss 5.8688 Accuracy 0.1363
# Epoch 1 Batch 3900 Loss 5.8624 Accuracy 0.1366
# Epoch 1 Batch 3950 Loss 5.8570 Accuracy 0.1369
# Epoch 1 Batch 4000 Loss 5.8522 Accuracy 0.1371
# Saving checkpoint for epoch 1 and for Batch 4000 at ./checkpoints/train\ckpt-9
# Epoch 1 Batch 4050 Loss 5.8462 Accuracy 0.1374
# Epoch 1 Batch 4100 Loss 5.8408 Accuracy 0.1376
# Epoch 1 Batch 4150 Loss 5.8355 Accuracy 0.1377
# Epoch 1 Batch 4200 Loss 5.8308 Accuracy 0.1379
# Epoch 1 Batch 4250 Loss 5.8256 Accuracy 0.1381
# Epoch 1 Batch 4300 Loss 5.8210 Accuracy 0.1383
# Epoch 1 Batch 4350 Loss 5.8160 Accuracy 0.1386
# Epoch 1 Batch 4400 Loss 5.8120 Accuracy 0.1388
# Epoch 1 Batch 4450 Loss 5.8075 Accuracy 0.1390
# Epoch 1 Batch 4500 Loss 5.8028 Accuracy 0.1393
# Saving checkpoint for epoch 1 and for Batch 4500 at ./checkpoints/train\ckpt-10
# Epoch 1 Batch 4550 Loss 5.7981 Accuracy 0.1395
# Epoch 1 Batch 4600 Loss 5.7930 Accuracy 0.1398
# Epoch 1 Batch 4650 Loss 5.7879 Accuracy 0.1401
# Epoch 1 Batch 4700 Loss 5.7823 Accuracy 0.1405
# Epoch 1 Batch 4750 Loss 5.7777 Accuracy 0.1408
# Epoch 1 Batch 4800 Loss 5.7724 Accuracy 0.1410
# Epoch 1 Batch 4850 Loss 5.7680 Accuracy 0.1412
# Epoch 1 Batch 4900 Loss 5.7634 Accuracy 0.1415
# Epoch 1 Batch 4950 Loss 5.7595 Accuracy 0.1417
# Epoch 1 Batch 5000 Loss 5.7544 Accuracy 0.1419
# Saving checkpoint for epoch 1 and for Batch 5000 at ./checkpoints/train\ckpt-11
# Epoch 1 Batch 5050 Loss 5.7494 Accuracy 0.1422
# Epoch 1 Batch 5100 Loss 5.7450 Accuracy 0.1424
# Epoch 1 Batch 5150 Loss 5.7407 Accuracy 0.1426
# Epoch 1 Batch 5200 Loss 5.7356 Accuracy 0.1430
# Epoch 1 Batch 5250 Loss 5.7315 Accuracy 0.1433
# Epoch 1 Batch 5300 Loss 5.7270 Accuracy 0.1435
# Epoch 1 Batch 5350 Loss 5.7227 Accuracy 0.1438
# Epoch 1 Batch 5400 Loss 5.7186 Accuracy 0.1441
# Epoch 1 Batch 5450 Loss 5.7146 Accuracy 0.1444
# Epoch 1 Batch 5500 Loss 5.7108 Accuracy 0.1447
# Saving checkpoint for epoch 1 and for Batch 5500 at ./checkpoints/train\ckpt-12
# Epoch 1 Batch 5550 Loss 5.7066 Accuracy 0.1450
# Epoch 1 Batch 5600 Loss 5.7027 Accuracy 0.1452
# Epoch 1 Batch 5650 Loss 5.6992 Accuracy 0.1454
# Epoch 1 Batch 5700 Loss 5.6958 Accuracy 0.1456
# Epoch 1 Batch 5750 Loss 5.6921 Accuracy 0.1458
# Epoch 1 Batch 5800 Loss 5.6885 Accuracy 0.1460
# Epoch 1 Batch 5850 Loss 5.6848 Accuracy 0.1463
# Epoch 1 Batch 5900 Loss 5.6807 Accuracy 0.1465
# Epoch 1 Batch 5950 Loss 5.6768 Accuracy 0.1468
# Epoch 1 Batch 6000 Loss 5.6730 Accuracy 0.1471
# Saving checkpoint for epoch 1 and for Batch 6000 at ./checkpoints/train\ckpt-13
# Epoch 1 Batch 6050 Loss 5.6691 Accuracy 0.1474
# Epoch 1 Batch 6100 Loss 5.6654 Accuracy 0.1477
# Epoch 1 Batch 6150 Loss 5.6612 Accuracy 0.1481
# Epoch 1 Batch 6200 Loss 5.6573 Accuracy 0.1483
# Epoch 1 Batch 6250 Loss 5.6540 Accuracy 0.1485
# Epoch 1 Batch 6300 Loss 5.6503 Accuracy 0.1487
# Epoch 1 Batch 6350 Loss 5.6466 Accuracy 0.1490
# Epoch 1 Batch 6400 Loss 5.6428 Accuracy 0.1493
# Epoch 1 Batch 6450 Loss 5.6401 Accuracy 0.1495
# Epoch 1 Batch 6500 Loss 5.6368 Accuracy 0.1497
# Saving checkpoint for epoch 1 and for Batch 6500 at ./checkpoints/train\ckpt-14
# Epoch 1 Batch 6550 Loss 5.6338 Accuracy 0.1499
# Epoch 1 Batch 6600 Loss 5.6307 Accuracy 0.1501
# Epoch 1 Batch 6650 Loss 5.6272 Accuracy 0.1503
# Epoch 1 Batch 6700 Loss 5.6235 Accuracy 0.1506
# Epoch 1 Batch 6750 Loss 5.6198 Accuracy 0.1509
# Epoch 1 Batch 6800 Loss 5.6165 Accuracy 0.1512
# Epoch 1 Batch 6850 Loss 5.6129 Accuracy 0.1515
# Epoch 1 Batch 6900 Loss 5.6098 Accuracy 0.1517
# Epoch 1 Batch 6950 Loss 5.6066 Accuracy 0.1519
# Epoch 1 Batch 7000 Loss 5.6035 Accuracy 0.1521
# Saving checkpoint for epoch 1 and for Batch 7000 at ./checkpoints/train\ckpt-15
# Epoch 1 Batch 7050 Loss 5.6003 Accuracy 0.1523
# Epoch 1 Batch 7100 Loss 5.5972 Accuracy 0.1525
# Epoch 1 Batch 7150 Loss 5.5949 Accuracy 0.1527
# Epoch 1 Batch 7200 Loss 5.5918 Accuracy 0.1530
# Epoch 1 Batch 7250 Loss 5.5888 Accuracy 0.1532
# Epoch 1 Batch 7300 Loss 5.5864 Accuracy 0.1533
# Epoch 1 Batch 7350 Loss 5.5839 Accuracy 0.1535
# Epoch 1 Batch 7400 Loss 5.5810 Accuracy 0.1537
# Epoch 1 Batch 7450 Loss 5.5785 Accuracy 0.1539
# Epoch 1 Batch 7500 Loss 5.5752 Accuracy 0.1542
# Saving checkpoint for epoch 1 and for Batch 7500 at ./checkpoints/train\ckpt-16
# Epoch 1 Batch 7550 Loss 5.5730 Accuracy 0.1543
# Epoch 1 Batch 7600 Loss 5.5700 Accuracy 0.1546
# Epoch 1 Batch 7650 Loss 5.5672 Accuracy 0.1548
# Epoch 1 Batch 7700 Loss 5.5651 Accuracy 0.1549
# Epoch 1 Batch 7750 Loss 5.5623 Accuracy 0.1551
# Epoch 1 Batch 7800 Loss 5.5599 Accuracy 0.1553
# Epoch 1 Batch 7850 Loss 5.5569 Accuracy 0.1555
# Epoch 1 Batch 7900 Loss 5.5544 Accuracy 0.1557
# Epoch 1 Batch 7950 Loss 5.5516 Accuracy 0.1559
# Epoch 1 Batch 8000 Loss 5.5490 Accuracy 0.1561
# Saving checkpoint for epoch 1 and for Batch 8000 at ./checkpoints/train\ckpt-17
# Epoch 1 Batch 8050 Loss 5.5467 Accuracy 0.1564
# Epoch 1 Batch 8100 Loss 5.5442 Accuracy 0.1566
# Epoch 1 Batch 8150 Loss 5.5415 Accuracy 0.1568
# Epoch 1 Batch 8200 Loss 5.5393 Accuracy 0.1569
# Epoch 1 Batch 8250 Loss 5.5366 Accuracy 0.1571
# Epoch 1 Batch 8300 Loss 5.5344 Accuracy 0.1573
# Epoch 1 Batch 8350 Loss 5.5316 Accuracy 0.1575
# Epoch 1 Batch 8400 Loss 5.5292 Accuracy 0.1577
# Epoch 1 Batch 8450 Loss 5.5270 Accuracy 0.1578
# Epoch 1 Batch 8500 Loss 5.5249 Accuracy 0.1579
# Saving checkpoint for epoch 1 and for Batch 8500 at ./checkpoints/train\ckpt-18
# Epoch 1 Batch 8550 Loss 5.5224 Accuracy 0.1581
# Epoch 1 Batch 8600 Loss 5.5204 Accuracy 0.1582
# Epoch 1 Batch 8650 Loss 5.5177 Accuracy 0.1585
# Epoch 1 Batch 8700 Loss 5.5150 Accuracy 0.1587
# Epoch 1 Batch 8750 Loss 5.5125 Accuracy 0.1588
# Epoch 1 Batch 8800 Loss 5.5106 Accuracy 0.1589
# Epoch 1 Batch 8850 Loss 5.5087 Accuracy 0.1591
# Epoch 1 Batch 8900 Loss 5.5062 Accuracy 0.1593
# Epoch 1 Batch 8950 Loss 5.5042 Accuracy 0.1594
# Saving checkpoint for epoch 1 at ./checkpoints/train\ckpt-19
# Epoch 1 Loss 5.5027 Accuracy 0.1595
# Time taken for 1 epoch: 5589.84 secs
#
# Latest checkpoint restored!!
# Epoch 2 Batch 0 Loss 5.1248 Accuracy 0.1595
# Saving checkpoint for epoch 2 and for Batch 0 at ./checkpoints/train\ckpt-20
# Epoch 2 Batch 50 Loss 5.0051 Accuracy 0.2016
# Epoch 2 Batch 100 Loss 5.0261 Accuracy 0.1947
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8972\2722794908.py in <module>
#      16     train_accuracy.reset_states()
#      17     for (batch, (inp, tar)) in enumerate(train_batches):
# ---> 18         train_step(inp, tar)
#      19
#      20
#
# ~\AppData\Local\Temp\ipykernel_8972\857204534.py in train_step(inp, tar)
#      14
#      15     with tf.GradientTape() as tape:
# ---> 16         predictions, _ = transformer([inp, tar_inp],
#      17                                  training = True)
#      18         loss = loss_function(tar_real, predictions)
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\keras\engine\training.py in __call__(self, *args, **kwargs)
#     555             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     556
# --> 557         return super().__call__(*args, **kwargs)
#     558
#     559     @doc_controls.doc_in_current_and_subclasses
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1095                     self._compute_dtype_object
#    1096                 ):
# -> 1097                     outputs = call_fn(inputs, *args, **kwargs)
#    1098
#    1099                 if self._activity_regularizer:
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# ~\AppData\Local\Temp\ipykernel_8972\1018454782.py in call(self, inputs, training)
#     305
#     306         # dec_output.shape == (batch_size, tar_seq_len, d_model)
# --> 307         dec_output, attention_weights = self.decoder(
#     308             tar, enc_output, training, look_ahead_mask, dec_padding_mask)
#     309
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1095                     self._compute_dtype_object
#    1096                 ):
# -> 1097                     outputs = call_fn(inputs, *args, **kwargs)
#    1098
#    1099                 if self._activity_regularizer:
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# ~\AppData\Local\Temp\ipykernel_8972\1018454782.py in call(self, x, enc_output, training, look_ahead_mask, padding_mask)
#     274
#     275         for i in range(self.num_layers):
# --> 276             x, block1, block2 = self.dec_layers[i](x, enc_output, training,
#     277                                                  look_ahead_mask, padding_mask)
#     278
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1095                     self._compute_dtype_object
#    1096                 ):
# -> 1097                     outputs = call_fn(inputs, *args, **kwargs)
#    1098
#    1099                 if self._activity_regularizer:
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# ~\AppData\Local\Temp\ipykernel_8972\1018454782.py in call(self, x, enc_output, training, look_ahead_mask, padding_mask)
#     207
#     208         ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
# --> 209         ffn_output = self.dropout3(ffn_output, training=training)
#     210         out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
#     211
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1095                     self._compute_dtype_object
#    1096                 ):
# -> 1097                     outputs = call_fn(inputs, *args, **kwargs)
#    1098
#    1099                 if self._activity_regularizer:
#
# E:\ANACONDA\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# E:\ANACONDA\lib\site-packages\keras\layers\regularization\dropout.py in call(self, inputs, training)
#     114             )
#     115
# --> 116         output = control_flow_util.smart_cond(
#     117             training, dropped_inputs, lambda: tf.identity(inputs)
#     118         )
#
# E:\ANACONDA\lib\site-packages\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     106     if isinstance(pred, tf.Variable):
#     107         return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108     return tf.__internal__.smart_cond.smart_cond(
#     109         pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110     )
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      50   if pred_value is not None:
#      51     if pred_value:
# ---> 52       return true_fn()
#      53     else:
#      54       return false_fn()
#
# E:\ANACONDA\lib\site-packages\keras\layers\regularization\dropout.py in dropped_inputs()
#     110
#     111         def dropped_inputs():
# --> 112             return self._random_generator.dropout(
#     113                 inputs, self.rate, noise_shape=self._get_noise_shape(inputs)
#     114             )
#
# E:\ANACONDA\lib\site-packages\keras\backend.py in dropout(self, inputs, rate, noise_shape)
#    2160                 seed=self.make_seed_for_stateless_op(),
#    2161             )
# -> 2162         return tf.nn.dropout(
#    2163             inputs,
#    2164             rate=rate,
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\ops\nn_ops.py in dropout_v2(x, rate, noise_shape, seed, name)
#    5506   def dummy_rng_step():
#    5507     random_seed.get_seed(seed)
# -> 5508   return _dropout(x=x, rate=rate, noise_shape=noise_shape,
#    5509                   uniform_sampler=uniform_sampler,
#    5510                   dummy_rng_step=dummy_rng_step, name=name,
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\ops\nn_ops.py in _dropout(x, rate, noise_shape, uniform_sampler, dummy_rng_step, name, default_name)
#    5727     # Sample a uniform distribution on [0.0, 1.0) and select values larger
#    5728     # than or equal to `rate`.
# -> 5729     random_tensor = uniform_sampler(shape=noise_shape, dtype=x_dtype)
#    5730     keep_mask = random_tensor >= rate
#    5731     ret = gen_math_ops.mul(ret, gen_math_ops.cast(keep_mask, x_dtype))
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\ops\random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     307           shape, minval, maxval, seed=seed1, seed2=seed2, name=name)
#     308     else:
# --> 309       result = gen_random_ops.random_uniform(
#     310           shape, dtype, seed=seed1, seed2=seed2)
#     311       if minval_is_zero:
#
# E:\ANACONDA\lib\site-packages\tensorflow\python\ops\gen_random_ops.py in random_uniform(shape, dtype, seed, seed2, name)
#     713   if tld.is_eager:
#     714     try:
# --> 715       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     716         _ctx, "RandomUniform", name, shape, "seed", seed, "seed2", seed2,
#     717         "dtype", dtype)
#
# KeyboardInterrupt:

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
class Translator(tf.Module):
    def __init__(self, embed, transformer):
        self.embed = embed
        self.transformer = transformer
        checkpoint_path = "./checkpoints/train"

        ckpt = tf.train.Checkpoint(transformer=transformer,
                               optimizer=optimizer)

        ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

        if ckpt_manager.latest_checkpoint:
            ckpt.restore(ckpt_manager.latest_checkpoint)
            print('Latest checkpoint restored!!')

    def __call__(self, sentence, max_length=20):
    # input sentence is portuguese, hence adding the start and end token
        data=[]
        dataes=[]
        datapt=[]
        dataes.append(sentence)
        data.append(dataes)
        data.append(datapt)
        sentence=self.embed.tokenize(data)
        encoder_input = sentence[0]
        print(encoder_input)
        # as the target is english, the first token to the transformer should be the
        # english start token.
        start = sentence[0][0][0][tf.newaxis]#WE USE THE IDS IN spanish BECAUSE THEY ARE THE SAME IN PT
        end = sentence[0][0][-1][tf.newaxis] #there could be some padding!
        print(start)
        print(end)
        # `tf.TensorArray` is required here (instead of a python list) so that the
        # dynamic-loop can be traced by `tf.function`.
        output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
        output_array = output_array.write(0, start)

        for i in tf.range(max_length):
            output = tf.transpose(output_array.stack())
            predictions, _ = self.transformer([encoder_input, output], training=False)

          # select the last token from the seq_len dimension
            predictions = predictions[:, -1:, :]  # (batch_size, 1, vocab_size)

            predicted_id = tf.argmax(predictions, axis=-1)

          # concatentate the predicted_id to the output which is given to the decoder
          # as its input.
            output_array = output_array.write(i+1, predicted_id[0])

            if predicted_id == end:
                break

        output = tf.transpose(output_array.stack())
    # output.shape (1, tokens)
        data=[]
        data.append([[2]])
        data.append(output[tf.newaxis][0])
        print(data)
        text = (self.embed.detokenize(data)[1].numpy())[0]
        print(text)# shape: ()

        # `tf.function` prevents us from using the attention_weights that were
        # calculated on the last iteration of the loop. So recalculate them outside
        # the loop.
        _, attention_weights = self.transformer([encoder_input, output[:,:-1]], training=False)

        return text, attention_weights

# %%
Embed=Embedding()
translator=Translator(Embed,transformer)
# Out:
# Latest checkpoint restored!!

# %%
def print_translation(sentence, text, ground_truth):
    print(f'{"Input:":15s}: {sentence}')
    print(f'{"Prediction":15s}: {text.decode("utf-8")}')
    print(f'{"Ground truth":15s}: {ground_truth}')

# %%
sentence = "hola, que tal."
ground_truth = "oi, como vai."

# %%
translated_text, attention_weights = translator((sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# tf.Tensor([[   2 1647   14  189  416   16    3]], shape=(1, 7), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# [[[2]], <tf.Tensor: shape=(1, 12), dtype=int64, numpy=
# array([[   2,   48,  353,    9,   58,   40,  167,  394,   46, 3658,   16,
#            3]], dtype=int64)>]
# b"[START] it ' s a very good . [END]"
# Input:         : hola, que tal.
# Prediction     : [START] it ' s a very good . [END]
# Ground truth   : oi, como vai.
